# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielCannete/DanielCanneteT1/blob/main/Castores_gr%C3%A1fica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

labels = 'Producción de madera', 'Ganado no producido-Carbono capturado', 'Biodiversidad','Recursos de investigación'
sizes = [83, 3, 9, 5]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x796a077cb880>,
# ...
#  [Text(-0.9468162003458401, 0.5599456069679145, 'Producción de madera'),
#   Text(0.6182916183185512, -0.9097886978397935, 'Ganado no producido-Carbono capturado'),
#   Text(0.9097885712083761, -0.6182918046510254, 'Biodiversidad'),
#   Text(1.0864571601546607, -0.17207800309356905, 'Recursos de investigación')])
